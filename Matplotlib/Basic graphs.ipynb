# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = [0,1,2,3,4,5]
y = [0,2,4,6,8,9]

plt.figure(figsize=(5,3), dpi=100)
plt.plot(x,y, label = '2x', color='blue',linestyle='-', marker='^', markeredgecolor='yellow', markersize='10' )
plt.title('First Graph ever', fontdict={'fontname': 'Gill Sans MT', 'fontsize':  20})
plt.xlabel('Men', fontdict={'fontname': 'Gill Sans MT', 'fontsize':  15})
plt.ylabel('Women', fontdict={'fontname': 'Gill Sans MT', 'fontsize':  15})

plt.xticks([0,2,4,6,7])
plt.yticks([0,2,4,6,8,15])

x2 = np.arange(0,4.5,0.5)
plt.plot(x2, x2**2, color='red')


plt.legend()

plt.savefig('mygraph.png', dpi=300)

plt.show()
