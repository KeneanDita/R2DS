# %%
import matplotlib.pyplot as plt
import pandas as pd

fifa = pd.read_csv('fifa_data.csv')
# Set the figure size and style
plt.figure(figsize=(8, 5), dpi=100)
plt.style.use('ggplot')

# Clean up the 'Weight' column
fifa.Weight = [int(x.strip('lbs')) if isinstance(x, str) else x for x in fifa.Weight]

# Calculate the number of players in each weight category
light = fifa.loc[fifa.Weight < 125].shape[0]
light_medium = fifa[(fifa.Weight >= 125) & (fifa.Weight < 150)].shape[0]
medium = fifa[(fifa.Weight >= 150) & (fifa.Weight < 175)].shape[0]
medium_heavy = fifa[(fifa.Weight >= 175) & (fifa.Weight < 200)].shape[0]
heavy = fifa[fifa.Weight >= 200].shape[0]

# Create a list of values and labels for the pie chart
weights = [light, light_medium, medium, medium_heavy, heavy]
labels = ['Under 125 lbs', '125-150 lbs', '150-175 lbs', '175-200 lbs', 'Over 200 lbs']

# Explode specific slices for emphasis
explode = (.4, .2, 0, 0, .4)

# Create a color palette with sufficient contrast
colors = ['#E57373', '#FFB74D', '#81C784', '#64B5F6', '#9575CD']

# Create the pie chart with customization
plt.title('Weight of Professional Soccer Players (lbs)', fontsize=16, fontweight='bold', color='darkblue', pad=20)

plt.pie(weights, labels=labels, explode=explode, autopct='%.2f %%', pctdistance=0.85, 
        startangle=140, colors=colors, wedgeprops={'edgecolor': 'black', 'linewidth': 1.5})

# Add a "doughnut" effect by adding a white circle in the middle (creating a ring)
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

# Display the pie chart
plt.show()
